# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/训练数据.csv')

# %%
data.reset_index(drop = True,inplace = True)
data
# Out:
#             date  黄金期货价格  论坛情绪值    美元指数  WTI原油     道琼斯指数  标普500指数  美联储利率  \
# 0     2014-08-11  260.55    0.0   81.47  98.08  16569.98  1936.90   0.25
# 1     2014-08-12  261.00    1.0   81.50  97.37  16560.54  1933.80   0.25
# 2     2014-08-13  261.05    0.0   81.60  97.59  16651.80  1946.70   0.25
# 3     2014-08-14  261.65    0.0   81.59  95.58  16713.58  1955.20   0.25
# 4     2014-08-15  261.40    1.0   81.42  97.35  16662.91  1955.10   0.25
# ...          ...     ...    ...     ...    ...       ...      ...    ...
# 2430  2024-08-05  559.94    1.0  102.69  72.94  38703.27  5186.33   5.50
# 2431  2024-08-06  554.18    0.0  102.97  73.20  38997.66  5240.03   5.50
# 2432  2024-08-07  556.06    0.0  103.20  75.23  38763.45  5199.50   5.50
# 2433  2024-08-08  556.10    1.0  103.21  76.19  39446.49  5319.31   5.50
# 2434  2024-08-09  560.70    0.0  103.14  76.84  39497.54  5344.16   5.50
#
#       美国CPI月率     GPR        GEPU
# 0         0.3  136.45   99.641198
# 1         0.3  136.45   99.641198
# 2         0.3  136.45   99.641198
# 3         0.3  136.45   99.641198
# 4         0.3  136.45   99.641198
# ...       ...     ...         ...
# 2430     -0.1  137.93  219.498876
# 2431     -0.1  137.93  219.498876
# 2432     -0.1  137.93  219.498876
# 2433     -0.1  137.93  219.498876
# 2434     -0.1  137.93  219.498876
#
# [2435 rows x 11 columns]

# %%
data['论坛情绪值0'] = data['论坛情绪值']
tag = 0 # 0为不改变，1为改变
states = data.loc[0,'论坛情绪值']   #首次状态值
for i in range(len(data)-1):
    if data.loc[i+1,'论坛情绪值'] != states:
        tag = tag + 1
        if tag == 3:
            states = data.loc[i+1,'论坛情绪值']
            tag = 0
        else:
            data.loc[i+1,'论坛情绪值'] = states
    else:
        tag = 0
        states = data.loc[i+1,'论坛情绪值']

# %%
data['黄金期货价格'] = data['黄金期货价格'].apply(np.log)
data
# Out:
#             date    黄金期货价格  论坛情绪值    美元指数  WTI原油     道琼斯指数  标普500指数  美联储利率  \
# 0     2014-08-11  5.562795    0.0   81.47  98.08  16569.98  1936.90   0.25
# 1     2014-08-12  5.564520    0.0   81.50  97.37  16560.54  1933.80   0.25
# 2     2014-08-13  5.564712    0.0   81.60  97.59  16651.80  1946.70   0.25
# 3     2014-08-14  5.567008    0.0   81.59  95.58  16713.58  1955.20   0.25
# 4     2014-08-15  5.566052    0.0   81.42  97.35  16662.91  1955.10   0.25
# ...          ...       ...    ...     ...    ...       ...      ...    ...
# 2430  2024-08-05  6.327830    0.0  102.69  72.94  38703.27  5186.33   5.50
# 2431  2024-08-06  6.317490    0.0  102.97  73.20  38997.66  5240.03   5.50
# 2432  2024-08-07  6.320876    0.0  103.20  75.23  38763.45  5199.50   5.50
# 2433  2024-08-08  6.320948    0.0  103.21  76.19  39446.49  5319.31   5.50
# 2434  2024-08-09  6.329186    0.0  103.14  76.84  39497.54  5344.16   5.50
#
#       美国CPI月率     GPR        GEPU  论坛情绪值0
# 0         0.3  136.45   99.641198     0.0
# 1         0.3  136.45   99.641198     1.0
# 2         0.3  136.45   99.641198     0.0
# 3         0.3  136.45   99.641198     0.0
# 4         0.3  136.45   99.641198     1.0
# ...       ...     ...         ...     ...
# 2430     -0.1  137.93  219.498876     1.0
# 2431     -0.1  137.93  219.498876     0.0
# 2432     -0.1  137.93  219.498876     0.0
# 2433     -0.1  137.93  219.498876     1.0
# 2434     -0.1  137.93  219.498876     0.0
#
# [2435 rows x 12 columns]

# %%
x1 = []
y = []
for i in range(data.shape[0]-5):
    x1.append(data.loc[i:(i+4)][['黄金期货价格','论坛情绪值']].values)
    y.append(data.loc[i+5]['黄金期货价格'])

x1 = np.array(x1)
y = np.array(y)

# %%
x1 = x1.reshape(x1.shape[0],x1.shape[1]*x1.shape[2]) 
x1.shape
# Out:
# (2430, 10)

# %%
x1_train = x1[:1944]
y_train = y[:1944]

x1_test  = x1[1944:]
y_test  = y[1944:]

# %%
from sklearn.svm import SVR
## 建立SVM模型
svm = SVR().fit(x1_train,y_train)

# %%
pred = svm.predict(x1_test)

# %%
pred
# Out:
# array([5.89117243, 5.89993384, 5.89642466, 5.90007726, 5.90726852,
#        5.92412211, 5.923608  , 5.91267653, 5.91256933, 5.90462303,
#        5.89957616, 5.88852484, 5.88972731, 5.89113949, 5.89166083,
#        5.89235065, 5.89131402, 5.88858335, 5.88548409, 5.88516421,
#        5.88519686, 5.88500216, 5.887173  , 5.88956512, 5.89060534,
#        5.88989678, 5.88936307, 5.88711171, 5.89267816, 5.88725527,
#        5.89077991, 5.8969954 , 5.91494803, 5.91474123, 5.91434624,
#        5.91396366, 5.91543581, 5.91673934, 5.90996698, 5.91418905,
#        5.91100187, 5.90863561, 5.89814082, 5.89700065, 5.89627086,
#        5.89521404, 5.89337683, 5.89152871, 5.89253886, 5.89376429,
#        5.89507352, 5.89671298, 5.89859058, 5.90547885, 5.90054216,
#        5.9035951 , 5.89979133, 5.91574551, 5.91087875, 5.90860409,
#        5.90182116, 5.90648001, 5.91225224, 5.91553553, 5.91906801,
#        5.92046792, 5.92196266, 5.92224012, 5.92277596, 5.9226771 ,
#        5.92179286, 5.92139256, 5.92153184, 5.92255601, 5.92311849,
#        5.92357842, 5.92382279, 5.93191124, 5.92704747, 5.92892673,
#        5.9331256 , 5.94801945, 5.94589974, 5.93496561, 5.93686356,
#        5.93354878, 5.93907696, 5.92256489, 5.9269634 , 5.93371827,
#        5.95091814, 5.95275895, 5.95406615, 5.94458864, 5.94670122,
#        5.94048253, 5.93628438, 5.92656094, 5.92796902, 5.92986422,
#        5.93121448, 5.93152283, 5.93270572, 5.9335921 , 5.93418155,
#        5.93490947, 5.9368401 , 5.93801523, 5.93988286, 5.94112234,
#        5.94286129, 5.94573818, 5.94758072, 5.94766738, 5.94871498,
#        5.95052148, 5.94906417, 5.95311288, 5.94664597, 5.94738529,
#        5.94979259, 5.96342768, 5.96321214, 5.96326163, 5.96288169,
#        5.96216438, 5.9619317 , 5.96170268, 5.95125348, 5.95296751,
#        5.94714675, 5.94440823, 5.93319807, 5.93351774, 5.93393605,
#        5.93451697, 5.93540724, 5.93762242, 5.93977375, 5.94692371,
#        5.94298013, 5.9471962 , 5.95420154, 5.9736331 , 5.97796895,
#        5.98363237, 5.9889564 , 5.99736286, 6.00242728, 6.00517832,
#        6.04466232, 6.04480411, 6.04504699, 6.04385902, 6.04353221,
#        6.04343353, 6.04283924, 6.04151985, 6.0418045 , 6.0421171 ,
#        6.04237567, 6.04288904, 6.04430604, 6.04689648, 6.05161437,
#        6.05721817, 6.06403932, 6.07026899, 6.08223507, 6.08102525,
#        6.08672838, 6.09368046, 6.1112858 , 6.11007631, 6.10965095,
#        6.10968216, 6.11242544, 6.11366572, 6.11621541, 6.11861987,
#        6.1214954 , 6.12275556, 6.12796863, 6.13354031, 6.13895279,
#        6.14551756, 6.15455728, 6.16112417, 6.16732499, 6.17227684,
#        6.1794578 , 6.18165638, 6.18410244, 6.18624577, 6.18861173,
#        6.18815677, 6.18666841, 6.18096614, 6.17688439, 6.17322738,
#        6.17013488, 6.1684931 , 6.16955072, 6.16883048, 6.15896285,
#        6.15844211, 6.15074434, 6.14915686, 6.13967336, 6.14762548,
#        6.14646858, 6.15518542, 6.16326864, 6.18579979, 6.18996285,
#        6.19330476, 6.19188059, 6.18909794, 6.18361743, 6.17978357,
#        6.17673153, 6.17536211, 6.17593545, 6.17480586, 6.17490936,
#        6.17344674, 6.17550939, 6.17691822, 6.17492692, 6.17279658,
#        6.17146013, 6.16821189, 6.1652153 , 6.16652431, 6.16764584,
#        6.16988757, 6.16298685, 6.16409207, 6.15761253, 6.15186857,
#        6.13714724, 6.13529534, 6.13540934, 6.13555778, 6.13732249,
#        6.14049652, 6.14250707, 6.14476296, 6.146191  , 6.14748299,
#        6.1560709 , 6.15471548, 6.16132458, 6.17243918, 6.19463786,
#        6.19843111, 6.1975374 , 6.19661971, 6.19357657, 6.19095851,
#        6.18478273, 6.18266141, 6.18171173, 6.18163212, 6.18101931,
#        6.18475332, 6.18879004, 6.18824736, 6.1860818 , 6.18353259,
#        6.18003288])

# %%
df0 = pd.DataFrame(pred,columns=['pred'])
df = pd.DataFrame(y_test,columns=['truth'])
from sklearn import metrics

df = pd.concat([df, df0], axis=1)
MSE = metrics.mean_squared_error(np.exp(y_test), np.exp(pred))
RMSE = np.sqrt(metrics.mean_squared_error(np.exp(y_test), np.exp(pred)))
MAE = np.sqrt(metrics.mean_absolute_error(np.exp(y_test), np.exp(pred)))
MAPE = np.sqrt(metrics.mean_absolute_percentage_error(np.exp(y_test), np.exp(pred)))
print("MSE:",MSE)    
print("RMSE:",RMSE)
print("MAE:",MAE)  
print("MAPE:",MAPE)
df
# Out:
# MSE: 2793.96928393353
# RMSE: 52.85801059379297
# MAE: 7.010682797194525
# MAPE: 0.32065530511523066
#         truth      pred
# 0    5.969168  5.891172
# 1    5.965018  5.899934
# 2    5.969270  5.896425
# 3    5.971262  5.900077
# 4    5.970037  5.907269
# ..        ...       ...
# 481  6.327830  6.188790
# 482  6.317490  6.188247
# 483  6.320876  6.186082
# 484  6.320948  6.183533
# 485  6.329186  6.180033
#
# [486 rows x 2 columns]

# %%
df.to_csv('./data/SVR+修正论坛情绪值-预测值.csv',header=True,index=False)

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']    #用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False      #用来正常显示负号
plt.figure(figsize=(20,10))
plt.plot(np.exp(df.truth), 'r', label='真实价格')
plt.plot(np.exp(df.pred), '--', label='预测价格')
plt.title('上海期货交易所黄金期货价格预测')
plt.ylabel('黄金期货价格')
plt.legend()
plt.show()
