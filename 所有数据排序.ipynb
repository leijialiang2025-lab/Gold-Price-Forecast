# %%
import pandas as pd

# %%
data = pd.read_csv('./分词过的全部数据.csv')
data = data.reset_index()
data
# Out:
#          index         publish_time view_counts  \
# 0            0  2010-07-21 16:58:34        1244
# 1            1  2010-07-30 11:47:39        1863
# 2            2  2010-08-04 07:48:00        7636
# 3            3  2010-08-18 02:02:55         855
# 4            4  2010-08-19 09:49:28        2413
# ...        ...                  ...         ...
# 113111  113111  2024-08-09 23:39:20         101
# 113112  113112  2024-08-10 00:42:22          85
# 113113  113113  2024-08-10 02:23:27         125
# 113114  113114  2024-08-10 15:14:49         313
# 113115  113115  2024-08-11 11:03:00         147
#
#                                             summarization 相关性   涨跌  \
# 0       金价格在亚洲盘时段上行趋势线后遭遇强力阻力收出中等长度的下影线看涨的因素还在待到债务危机避险...   1  1.0
# 1          从日K线来看黄金处于交易日大幅走低跌破5日均线后大幅回落至200日平均线即115附近获得支撑   1  1.0
# 2       黄金每克价格太贵了没人买得起房子一样贵了工资十年没见涨落都在1000元左右一月下来也买不了多...   0  0.0
# 3       捕鱼收网现货金多头在1230美元上方获利平仓美国制造业数据降避险情绪继续升但是美元与黄金分道...   1  0.0
# ...

# %%
data1 = data[data['涨跌'] != 2]
data1 = data1.reset_index(drop=True)
data1
# Out:
#        index         publish_time view_counts  \
# 0          0  2010-07-21 16:58:34        1244
# 1          1  2010-07-30 11:47:39        1863
# 2          2  2010-08-04 07:48:00        7636
# 3          3  2010-08-18 02:02:55         855
# 4          4  2010-08-19 09:49:28        2413
# ...      ...                  ...         ...
# 4595  100595  2022-10-28 21:35:47         852
# 4596  100596  2022-10-29 10:14:12         708
# 4597  100597  2022-10-29 13:48:29         737
# 4598  100598  2022-10-29 21:23:45         417
# 4599  100599  2022-10-30 16:54:34         476
#
#                                           summarization 相关性   涨跌  \
# 0     金价格在亚洲盘时段上行趋势线后遭遇强力阻力收出中等长度的下影线看涨的因素还在待到债务危机避险...   1  1.0
# 1        从日K线来看黄金处于交易日大幅走低跌破5日均线后大幅回落至200日平均线即115附近获得支撑   1  1.0
# 2     黄金每克价格太贵了没人买得起房子一样贵了工资十年没见涨落都在1000元左右一月下来也买不了多...   0  0.0
# 3     捕鱼收网现货金多头在1230美元上方获利平仓美国制造业数据降避险情绪继续升但是美元与黄金分道...   1  0.0
# 4              这里是不是做黄金的比较多小弟有意向往这方面发展可惜不太了解希望老手们有空多多指教   1  1.0
# ...

# %%
data2 = data[data['涨跌'] == 2]
data2 = data2.reset_index(drop=True)
data2
# Out:
#          index         publish_time view_counts  \
# 0         3000  2012-01-06 13:40:29         411
# 1         3001  2012-01-06 15:44:23         709
# 2         3002  2012-01-06 18:37:43         533
# 3         3003  2012-01-07 00:07:23        1532
# 4         3004  2012-01-07 11:30:22        1.1万
# ...        ...                  ...         ...
# 108511  113111  2024-08-09 23:39:20         101
# 108512  113112  2024-08-10 00:42:22          85
# 108513  113113  2024-08-10 02:23:27         125
# 108514  113114  2024-08-10 15:14:49         313
# 108515  113115  2024-08-11 11:03:00         147
#
#                                             summarization 相关性   涨跌  \
# 0       在全球通货膨胀加剧的情况下黄金价格在过去的一年中首次走高而每周平均每盎司美元兑换1.18元人...   N  2.0
# 1                          美国非农数据和美国经济数据的短线可能会对黄金提供进一步支持。   N  2.0
# 2                  年底都是黄金的消费旺季上了1660就是空头们最佳建仓良机相信下星期就能见到了   N  2.0
# 3                              黄金照我去战斗小小黄金网中游巍巍K图两岸走钞票展翅飞   N  2.0
# ...

# %%
data3 = pd.concat([data4, data2], axis=0, ignore_index=True)
data3
# Out:
#          index         publish_time view_counts  \
# 0         2504  2011-11-17 11:51:43        8386
# 1         2546  2011-11-21 16:09:15         497
# 2          252  2011-01-13 10:04:24        1012
# 3         2285  2011-10-26 08:44:09         676
# 4         1907  2011-09-14 13:57:52         506
# ...        ...                  ...         ...
# 113111  113111  2024-08-09 23:39:20         101
# 113112  113112  2024-08-10 00:42:22          85
# 113113  113113  2024-08-10 02:23:27         125
# 113114  113114  2024-08-10 15:14:49         313
# 113115  113115  2024-08-11 11:03:00         147
#
#                                             summarization 相关性   涨跌  \
# 0                                黄金周五跌破每盎司1300美元,创下历史最高点。   1  0.0
# 1       周一(11月21日)亚市盘中国际现货黄金跟随风险资产下跌且逐渐修复与美元的负相关关联盤中探底...   1  0.0
# 2       新年伊始金价出现近一年以来的最大单日跌幅随后的3个交易日金价格出现了缓跌现象11日黄金重上1...   1  1.0
# 3           黄金周二10月25日大涨一个多月来首次突破1700美元大关变身为避险资产与股市走势突然分离   1  1.0
# ...

# %%
data4 = data1.sample(frac=1).reset_index(drop=True)
data4
# Out:
#       index         publish_time view_counts  \
# 0      2504  2011-11-17 11:51:43        8386
# 1      2546  2011-11-21 16:09:15         497
# 2       252  2011-01-13 10:04:24        1012
# 3      2285  2011-10-26 08:44:09         676
# 4      1907  2011-09-14 13:57:52         506
# ...     ...                  ...         ...
# 4595   1326  2011-08-05 12:05:39        1300
# 4596  50367  2015-12-17 14:45:02        4482
# 4597   1557  2011-08-21 21:02:54         741
# 4598  80002  2019-09-21 10:13:20        2596
# 4599  30028  2014-06-13 20:11:19        1254
#
#                                           summarization 相关性   涨跌  \
# 0                              黄金周五跌破每盎司1300美元,创下历史最高点。   1  0.0
# 1     周一(11月21日)亚市盘中国际现货黄金跟随风险资产下跌且逐渐修复与美元的负相关关联盤中探底...   1  0.0
# 2     新年伊始金价出现近一年以来的最大单日跌幅随后的3个交易日金价格出现了缓跌现象11日黄金重上1...   1  1.0
# 3         黄金周二10月25日大涨一个多月来首次突破1700美元大关变身为避险资产与股市走势突然分离   1  1.0
# 4                  对于投资者来说是实金交易和纸黄金交易是投资的必不可少的其中一个主要原因是   0  0.0
# ...

# %%
df_filtered = data4[data4['相关性'] == '11']
df_filtered
# Out:
# Empty DataFrame
# Columns: [index, publish_time, view_counts, summarization, 相关性, 涨跌, x]
# Index: []

# %%
data4.loc[744, '相关性'] = 1

# %%
data3.to_csv('./9月6日处理完的所有数据.csv', index=False)
