# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/训练数据.csv')

# %%
data
# Out:
#             date  黄金期货价格  论坛情绪值    美元指数  WTI原油     道琼斯指数  标普500指数  美联储利率  \
# 0     2014-08-11  260.55    0.0   81.47  98.08  16569.98  1936.90   0.25
# 1     2014-08-12  261.00    1.0   81.50  97.37  16560.54  1933.80   0.25
# 2     2014-08-13  261.05    0.0   81.60  97.59  16651.80  1946.70   0.25
# 3     2014-08-14  261.65    0.0   81.59  95.58  16713.58  1955.20   0.25
# 4     2014-08-15  261.40    1.0   81.42  97.35  16662.91  1955.10   0.25
# ...          ...     ...    ...     ...    ...       ...      ...    ...
# 2430  2024-08-05  559.94    1.0  102.69  72.94  38703.27  5186.33   5.50
# 2431  2024-08-06  554.18    0.0  102.97  73.20  38997.66  5240.03   5.50
# 2432  2024-08-07  556.06    0.0  103.20  75.23  38763.45  5199.50   5.50
# 2433  2024-08-08  556.10    1.0  103.21  76.19  39446.49  5319.31   5.50
# 2434  2024-08-09  560.70    0.0  103.14  76.84  39497.54  5344.16   5.50
#
#       美国CPI月率     GPR        GEPU
# 0         0.3  136.45   99.641198
# 1         0.3  136.45   99.641198
# 2         0.3  136.45   99.641198
# 3         0.3  136.45   99.641198
# 4         0.3  136.45   99.641198
# ...       ...     ...         ...
# 2430     -0.1  137.93  219.498876
# 2431     -0.1  137.93  219.498876
# 2432     -0.1  137.93  219.498876
# 2433     -0.1  137.93  219.498876
# 2434     -0.1  137.93  219.498876
#
# [2435 rows x 11 columns]

# %%
data['date'] = pd.to_datetime(data['date'], format = '%Y-%m-%d')
data
# Out:
#            date  黄金期货价格  论坛情绪值    美元指数  WTI原油     道琼斯指数  标普500指数  美联储利率  \
# 0    2014-08-11  260.55    0.0   81.47  98.08  16569.98  1936.90   0.25
# 1    2014-08-12  261.00    1.0   81.50  97.37  16560.54  1933.80   0.25
# 2    2014-08-13  261.05    0.0   81.60  97.59  16651.80  1946.70   0.25
# 3    2014-08-14  261.65    0.0   81.59  95.58  16713.58  1955.20   0.25
# 4    2014-08-15  261.40    1.0   81.42  97.35  16662.91  1955.10   0.25
# ...         ...     ...    ...     ...    ...       ...      ...    ...
# 2430 2024-08-05  559.94    1.0  102.69  72.94  38703.27  5186.33   5.50
# 2431 2024-08-06  554.18    0.0  102.97  73.20  38997.66  5240.03   5.50
# 2432 2024-08-07  556.06    0.0  103.20  75.23  38763.45  5199.50   5.50
# 2433 2024-08-08  556.10    1.0  103.21  76.19  39446.49  5319.31   5.50
# 2434 2024-08-09  560.70    0.0  103.14  76.84  39497.54  5344.16   5.50
#
#       美国CPI月率     GPR        GEPU
# 0         0.3  136.45   99.641198
# 1         0.3  136.45   99.641198
# 2         0.3  136.45   99.641198
# 3         0.3  136.45   99.641198
# 4         0.3  136.45   99.641198
# ...       ...     ...         ...
# 2430     -0.1  137.93  219.498876
# 2431     -0.1  137.93  219.498876
# 2432     -0.1  137.93  219.498876
# 2433     -0.1  137.93  219.498876
# 2434     -0.1  137.93  219.498876
#
# [2435 rows x 11 columns]

# %%
data['黄金期货价格'] = data['黄金期货价格'].apply(np.log)
data['美元指数'] = data['美元指数'].apply(np.log)
data['WTI原油'] = data['WTI原油'].apply(np.log)
data['道琼斯指数'] = data['道琼斯指数'].apply(np.log)
data['标普500指数'] = data['标普500指数'].apply(np.log)
data['美联储利率'] = data['美联储利率'].apply(np.log)
data['美国CPI月率'] = data['美国CPI月率'].apply(np.log)
data['GPR'] = data['GPR'].apply(np.log)
data['GEPU'] = data['GEPU'].apply(np.log)
data
# Out:
#            date    黄金期货价格  论坛情绪值      美元指数     WTI原油      道琼斯指数   标普500指数  \
# 0    2014-08-11  5.562795    0.0  4.400235  4.585783   9.715348  7.568844
# 1    2014-08-12  5.564520    1.0  4.400603  4.578518   9.714778  7.567242
# 2    2014-08-13  5.564712    0.0  4.401829  4.580775   9.720274  7.573891
# 3    2014-08-14  5.567008    0.0  4.401707  4.559964   9.723977  7.578248
# 4    2014-08-15  5.566052    1.0  4.399621  4.578313   9.720941  7.578197
# ...         ...       ...    ...       ...       ...        ...       ...
# 2430 2024-08-05  6.327830    1.0  4.631715  4.289637  10.563679  8.553782
# 2431 2024-08-06  6.317490    0.0  4.634438  4.293195  10.571257  8.564083
# 2432 2024-08-07  6.320876    0.0  4.636669  4.320550  10.565233  8.556318
# 2433 2024-08-08  6.320948    1.0  4.636766  4.333230  10.582700  8.579099
# 2434 2024-08-09  6.329186    0.0  4.636087  4.341725  10.583994  8.583760
#
#          美联储利率   美国CPI月率       GPR      GEPU
# 0    -1.386294 -1.203973  4.915958  4.601576
# 1    -1.386294 -1.203973  4.915958  4.601576
# 2    -1.386294 -1.203973  4.915958  4.601576
# 3    -1.386294 -1.203973  4.915958  4.601576
# 4    -1.386294 -1.203973  4.915958  4.601576
# ...        ...       ...       ...       ...
# 2430  1.704748       NaN  4.926746  5.391347
# 2431  1.704748       NaN  4.926746  5.391347
# 2432  1.704748       NaN  4.926746  5.391347
# 2433  1.704748       NaN  4.926746  5.391347
# 2434  1.704748       NaN  4.926746  5.391347
#
# [2435 rows x 11 columns]

# %%
x1 = []
x2 = []
y = []
for i in range(data.shape[0]-5):
    x1.append(data.loc[i:(i+4)][['黄金期货价格']].values)
    x2.append(data.loc[i:(i+4)][['美元指数','WTI原油','道琼斯指数','标普500指数','美联储利率','美国CPI月率','GPR','GEPU']].values)
    y.append(data.loc[i+5]['黄金期货价格'])

x1 = np.array(x1)
x2 = np.array(x2)
y = np.array(y)

# %%
x1.shape
# Out:
# (2430, 5, 1)

# %%
x2 = x2.reshape(x2.shape[0],x2.shape[1],8)
x2.shape
# Out:
# (2430, 5, 8)

# %%
x1_train = x1[:1944]
x2_train = x2[:1944]
y_train = y[:1944]

x1_test  = x1[1944:]
x2_test  = x2[1944:]
y_test  = y[1944:]

# %%
from sklearn import metrics

MSE = 0
RMSE = 0
MAE = 0
MAPE = 0
df = pd.DataFrame(y_test,columns=['truth'])

for i in range(5):
    from keras.models import Sequential
    from keras.layers import Input, Dense, LSTM, concatenate, multiply
    from tensorflow.keras.layers import BatchNormalization
    from tensorflow.keras.models import Model

    model1 = Sequential()
    input1 = Input(shape=(5,1))
    model1 = Dense(200, activation='relu')(input1)
    model1 = LSTM(units=200)(model1)
    model1 = (Dense(2000, activation="relu"))(model1)
    model1 = (Dense(200, activation="relu"))(model1)

    model2 = Sequential()
    input2 = Input(shape=(5,8))
    model2 = Dense(200, activation='relu')(input2)
    model2 = LSTM(units=200)(model2)
    model2 = (Dense(2000, activation="relu"))(model2)
    model2 = (Dense(200, activation="relu"))(model2)

    conc = multiply([model1, model2])

    conc2 = (Dense(10, activation="relu"))(conc)
    out = (Dense(1, activation="linear"))(conc2)
    model = Model([input1, input2], out)
    model.summary()

    from keras.optimizers import Adam
    adam = Adam(learning_rate=0.0001)
    model.compile(optimizer=adam, loss='mean_squared_error')
    model.fit([x1_train,x2_train],y_train,
                epochs=300,
                batch_size=256,
                validation_data=([x1_test,x2_test], y_test),
                verbose=1)

    pred = model.predict([x1_test,x2_test])
    pred = pred.ravel()
    df0 = pd.DataFrame(pred,columns=['pred'])
    df = pd.concat([df, df0], axis=1)
    MSE = MSE + metrics.mean_squared_error(np.exp(y_test), np.exp(pred))
    RMSE = RMSE + np.sqrt(metrics.mean_squared_error(np.exp(y_test), np.exp(pred)))
    MAE = MAE + np.sqrt(metrics.mean_absolute_error(np.exp(y_test), np.exp(pred)))
    MAPE = MAPE + np.sqrt(metrics.mean_absolute_percentage_error(np.exp(y_test), np.exp(pred)))

MSE = MSE/5
RMSE = RMSE/5
MAE = MAE/5
MAPE = MAPE/5

print("MSE:",MSE)    
print("RMSE:",RMSE)
print("MAE:",MAE)  
print("MAPE:",MAPE)
df
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 5, 1)]       0           []
#
#  input_2 (InputLayer)           [(None, 5, 8)]       0           []
#
#  dense (Dense)                  (None, 5, 200)       400         ['input_1[0][0]']
#
#  dense_3 (Dense)                (None, 5, 200)       1800        ['input_2[0][0]']
#
#  lstm (LSTM)                    (None, 200)          320800      ['dense[0][0]']
#
#  lstm_1 (LSTM)                  (None, 200)          320800      ['dense_3[0][0]']
#
#  dense_1 (Dense)                (None, 2000)         402000      ['lstm[0][0]']
#
#  dense_4 (Dense)                (None, 2000)         402000      ['lstm_1[0][0]']
#
#  dense_2 (Dense)                (None, 200)          400200      ['dense_1[0][0]']
#
#  dense_5 (Dense)                (None, 200)          400200      ['dense_4[0][0]']
#
#  multiply (Multiply)            (None, 200)          0           ['dense_2[0][0]',
#                                                                   'dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 10)           2010        ['multiply[0][0]']
#
#  dense_7 (Dense)                (None, 1)            11          ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 2,250,221
# Trainable params: 2,250,221
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/300
# 8/8 [==============================] - 6s 244ms/step - loss: nan - val_loss: nan
# Epoch 2/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 3/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 4/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 5/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 6/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 7/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 8/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 9/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 10/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 11/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 12/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 13/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 14/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 15/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 16/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 17/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 18/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 19/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 20/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 21/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 22/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 23/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 24/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 25/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 26/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 27/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 28/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 29/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 30/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 31/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 32/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 33/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 34/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 35/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 36/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 37/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 38/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 39/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 40/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 41/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 42/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 43/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 44/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 45/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 46/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 47/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 48/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 49/300
# 8/8 [==============================] - 0s 31ms/step - loss: nan - val_loss: nan
# Epoch 50/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 51/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 52/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 53/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 54/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 55/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 56/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 57/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 58/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 59/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 60/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 61/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 62/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 63/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 64/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 65/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 66/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 67/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 68/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 69/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 70/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 71/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 72/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 73/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 74/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 75/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 76/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 77/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 78/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 79/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 80/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 81/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 82/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 83/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 84/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 85/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 86/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 87/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 88/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 89/300
# 8/8 [==============================] - 0s 36ms/step - loss: nan - val_loss: nan
# Epoch 90/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 91/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 92/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 93/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 94/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 95/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 96/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 97/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 98/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 99/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 100/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 101/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 102/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 103/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 104/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 105/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 106/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 107/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 108/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 109/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 110/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 111/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 112/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 113/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 114/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 115/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 116/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 117/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 118/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 119/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 120/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 121/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 122/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 123/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 124/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 125/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 126/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 127/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 128/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 129/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 130/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 131/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 132/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 133/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 134/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 135/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 136/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 137/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 138/300
# 8/8 [==============================] - 0s 31ms/step - loss: nan - val_loss: nan
# Epoch 139/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 140/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 141/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 142/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 143/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 144/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 145/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 146/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 147/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 148/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 149/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 150/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 151/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 152/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 153/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 154/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 155/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 156/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 157/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 158/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 159/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 160/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 161/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 162/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 163/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 164/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 165/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 166/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 167/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 168/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 169/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 170/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 171/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 172/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 173/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 174/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 175/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 176/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 177/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 178/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 179/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 180/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 181/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 182/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 183/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 184/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 185/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 186/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 187/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 188/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 189/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 190/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 191/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 192/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 193/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 194/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 195/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 196/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 197/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 198/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 199/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 200/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 201/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 202/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 203/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 204/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 205/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 206/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 207/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 208/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 209/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 210/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 211/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 212/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 213/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 214/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 215/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 216/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 217/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 218/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 219/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 220/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 221/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 222/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 223/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 224/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 225/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 226/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 227/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 228/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 229/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 230/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 231/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 232/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 233/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 234/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 235/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 236/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 237/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 238/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 239/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 240/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 241/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 242/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 243/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 244/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 245/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 246/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 247/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 248/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 249/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 250/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 251/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 252/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 253/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 254/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 255/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 256/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 257/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 258/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 259/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 260/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 261/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 262/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 263/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 264/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 265/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 266/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 267/300
# 8/8 [==============================] - 0s 26ms/step - loss: nan - val_loss: nan
# Epoch 268/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 269/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 270/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 271/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 272/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 273/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 274/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 275/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 276/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# Epoch 277/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 278/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 279/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 280/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 281/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 282/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 283/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 284/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 285/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 286/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 287/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 288/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 289/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 290/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 291/300
# 8/8 [==============================] - 0s 31ms/step - loss: nan - val_loss: nan
# Epoch 292/300
# 8/8 [==============================] - 0s 27ms/step - loss: nan - val_loss: nan
# Epoch 293/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 294/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 295/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 296/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 297/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 298/300
# 8/8 [==============================] - 0s 29ms/step - loss: nan - val_loss: nan
# Epoch 299/300
# 8/8 [==============================] - 0s 28ms/step - loss: nan - val_loss: nan
# Epoch 300/300
# 8/8 [==============================] - 0s 30ms/step - loss: nan - val_loss: nan
# 16/16 [==============================] - 1s 8ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 49
#      47 df0 = pd.DataFrame(pred,columns=['pred'])
#      48 df = pd.concat([df, df0], axis=1)
# ---> 49 MSE = MSE + metrics.mean_squared_error(np.exp(y_test), np.exp(pred))
#      50 RMSE = RMSE + np.sqrt(metrics.mean_squared_error(np.exp(y_test), np.exp(pred)))
#      51 MAE = MAE + np.sqrt(metrics.mean_absolute_error(np.exp(y_test), np.exp(pred)))
#
# File ~\anaconda3\envs\tsGPU\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\anaconda3\envs\tsGPU\lib\site-packages\sklearn\metrics\_regression.py:506, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     501     if not squared:
#     502         return root_mean_squared_error(
#     503             y_true, y_pred, sample_weight=sample_weight, multioutput=multioutput
#     504         )
# --> 506 y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     507     y_true, y_pred, multioutput
#     508 )
#     509 check_consistent_length(y_true, y_pred, sample_weight)
#     510 output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\anaconda3\envs\tsGPU\lib\site-packages\sklearn\metrics\_regression.py:113, in _check_reg_targets(y_true, y_pred, multioutput, dtype, xp)
#     111 check_consistent_length(y_true, y_pred)
#     112 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# --> 113 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     115 if y_true.ndim == 1:
#     116     y_true = xp.reshape(y_true, (-1, 1))
#
# File ~\anaconda3\envs\tsGPU\lib\site-packages\sklearn\utils\validation.py:1064, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1058     raise ValueError(
#    1059         "Found array with dim %d. %s expected <= 2."
#    1060         % (array.ndim, estimator_name)
#    1061     )
#    1063 if force_all_finite:
# -> 1064     _assert_all_finite(
#    1065         array,
#    1066         input_name=input_name,
#    1067         estimator_name=estimator_name,
#    1068         allow_nan=force_all_finite == "allow-nan",
#    1069     )
#    1071 if copy:
#    1072     if _is_numpy_namespace(xp):
#    1073         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\anaconda3\envs\tsGPU\lib\site-packages\sklearn\utils\validation.py:123, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     120 if first_pass_isfinite:
#     121     return
# --> 123 _assert_all_finite_element_wise(
#     124     X,
#     125     xp=xp,
#     126     allow_nan=allow_nan,
#     127     msg_dtype=msg_dtype,
#     128     estimator_name=estimator_name,
#     129     input_name=input_name,
#     130 )
#
# File ~\anaconda3\envs\tsGPU\lib\site-packages\sklearn\utils\validation.py:172, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     155 if estimator_name and input_name == "X" and has_nan_error:
#     156     # Improve the error message on how to handle missing values in
#     157     # scikit-learn.
#     158     msg_err += (
#     159         f"\n{estimator_name} does not accept missing values"
#     160         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     170         "#estimators-that-handle-nan-values"
#     171     )
# --> 172 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %%
df.to_csv('./data/LSTM+传统因素-预测值.csv',header=True,index=False)

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']    #用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False      #用来正常显示负号
plt.figure(figsize=(20,10))
plt.plot(np.exp(df.truth), 'r', label='真实价格')
plt.plot(np.exp(df.pred), '--', label='预测价格')
plt.title('上海期货交易所黄金期货价格预测')
plt.ylabel('黄金期货价格')
plt.legend()
plt.show()
